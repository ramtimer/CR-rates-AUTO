# %%
import pandas as pd

# %%
df_ga_hits = pd.read_csv('ga_hits.csv')

# %%
df_ga_hits.head(20)
# Out:
#                                    session_id    hit_date   hit_time  \
# 0   5639623078712724064.1640254056.1640254056  2021-12-23   597864.0
# 1   7750352294969115059.1640271109.1640271109  2021-12-23   597331.0
# 2    885342191847998240.1640235807.1640235807  2021-12-23   796252.0
# 3    142526202120934167.1640211014.1640211014  2021-12-23   934292.0
# 4   3450086108837475701.1640265078.1640265078  2021-12-23   768741.0
# 5   6466333295973247896.1640246168.1640246168  2021-12-23   704194.0
# 6    281215510786615563.1640245516.1640245516  2021-12-23   911854.0
# 7   4024492994895054107.1640269084.1640269084  2021-12-23  1071804.0
# 8    555009234841130092.1640256620.1640256620  2021-12-23  1013899.0
# 9   2692901778487480807.1640206845.1640206845  2021-12-23        0.0
# 10  1945627655676404094.1640276355.1640276355  2021-12-23      197.0
# 11  4555345648396008371.1640233907.1640233907  2021-12-23      107.0
# 12  5636135307570360848.1640280592.1640280592  2021-12-23       12.0
# ...

# %%
df_ga_hits_copy = df_ga_hits.copy()

# %%
drop_list = ['hit_type','hit_time','hit_date','event_category','event_label','event_value']

# %%
df_ga_hits_copy = df_ga_hits_copy.drop(columns = drop_list)

# %%
df_ga_hits_copy.head(5)
# Out:
#                                   session_id  hit_number hit_referer  \
# 0  5639623078712724064.1640254056.1640254056          30         NaN
# 1  7750352294969115059.1640271109.1640271109          41         NaN
# 2   885342191847998240.1640235807.1640235807          49         NaN
# 3   142526202120934167.1640211014.1640211014          46         NaN
# 4  3450086108837475701.1640265078.1640265078          79         NaN
#
#                                        hit_page_path event_action
# 0  sberauto.com/cars?utm_source_initial=google&ut...    quiz_show
# 1  sberauto.com/cars/fiat?city=1&city=18&rental_c...    quiz_show
# 2  sberauto.com/cars/all/volkswagen/polo/e994838f...    quiz_show
# 3  sberauto.com/cars?utm_source_initial=yandex&ut...    quiz_show
# 4  sberauto.com/cars/all/mercedes-benz/cla-klasse...    quiz_show

# %%
df_ga_hits_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15726470 entries, 0 to 15726469
# Data columns (total 5 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   session_id     object
#  1   hit_number     int64
#  2   hit_referer    object
#  3   hit_page_path  object
#  4   event_action   object
# dtypes: int64(1), object(4)
# memory usage: 599.9+ MB

# %%
len(df_ga_hits_copy)
# Out:
# 15726470

# %%
df_ga_hits_copy.hit_referer = df_ga_hits_copy.hit_referer.fillna('other')

# %%
df_ga_hits_copy.isna().sum()
# Out:
# session_id       0
# hit_number       0
# hit_referer      0
# hit_page_path    0
# event_action     0
# dtype: int64

# %%
df_ga_sessions = pd.read_csv('ga_sessions.csv')
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_9656\434350226.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_ga_sessions = pd.read_csv('ga_sessions.csv')

# %%
df_ga_sessions.head(5)
# Out:
#                                   session_id          client_id  visit_date  \
# 0  9055434745589932991.1637753792.1637753792  2108382700.163776  2021-11-24
# 1   905544597018549464.1636867290.1636867290   210838531.163687  2021-11-14
# 2  9055446045651783499.1640648526.1640648526  2108385331.164065  2021-12-28
# 3  9055447046360770272.1622255328.1622255328  2108385564.162225  2021-05-29
# 4  9055447046360770272.1622255345.1622255345  2108385564.162225  2021-05-29
#
#   visit_time  visit_number            utm_source utm_medium  \
# 0   14:36:32             1  ZpYIoDJMcFzVoPFsHGJL     banner
# 1   08:21:30             1  MvfHsxITijuriZxsqZqt        cpm
# 2   02:42:06             1  ZpYIoDJMcFzVoPFsHGJL     banner
# 3   05:00:00             1  kjsLglQLzykiRbcDiGcD        cpc
# 4   05:00:00             2  kjsLglQLzykiRbcDiGcD        cpc
#
#            utm_campaign         utm_adcontent           utm_keyword  \
# 0  LEoPHuyFvzoNfnzGgfcd  vCIpmpaGBnIQhyYNkXqp  puhZPIYqKXeFPaUviSjo
# ...

# %%
drop_list_ga_s = ['device_screen_resolution', 'device_model','visit_time','visit_date','utm_adcontent']

# %%
df_ga_session_copy = df_ga_sessions.copy()

# %%
df_ga_session_copy = df_ga_session_copy.drop(columns = drop_list_ga_s)

# %%
df_ga_session_copy.head(5)
# Out:
#                                   session_id          client_id  visit_number  \
# 0  9055434745589932991.1637753792.1637753792  2108382700.163776             1
# 1   905544597018549464.1636867290.1636867290   210838531.163687             1
# 2  9055446045651783499.1640648526.1640648526  2108385331.164065             1
# 3  9055447046360770272.1622255328.1622255328  2108385564.162225             1
# 4  9055447046360770272.1622255345.1622255345  2108385564.162225             2
#
#              utm_source utm_medium          utm_campaign  \
# 0  ZpYIoDJMcFzVoPFsHGJL     banner  LEoPHuyFvzoNfnzGgfcd
# 1  MvfHsxITijuriZxsqZqt        cpm  FTjNLDyTrXaWYgZymFkV
# 2  ZpYIoDJMcFzVoPFsHGJL     banner  LEoPHuyFvzoNfnzGgfcd
# 3  kjsLglQLzykiRbcDiGcD        cpc                   NaN
# 4  kjsLglQLzykiRbcDiGcD        cpc                   NaN
#
#             utm_keyword device_category device_os device_brand  \
# 0  puhZPIYqKXeFPaUviSjo          mobile   Android       Huawei
# ...

# %%
df_ga_session_copy.isna().sum()
# Out:
# session_id         0
# client_id          0
# visit_number       0
# utm_source         0
# utm_medium         0
# utm_campaign       0
# utm_keyword        0
# device_category    0
# device_os          0
# device_brand       0
# device_browser     0
# geo_country        0
# geo_city           0
# dtype: int64

# %%
len(df_ga_session_copy)
# Out:
# 1860042

# %%
df_ga_session_copy.utm_keyword = df_ga_session_copy.utm_keyword.fillna('unknown')

# %%
df_ga_session_copy.device_os = df_ga_session_copy.device_os.fillna('unknown')

# %%
df_ga_session_copy.device_brand = df_ga_session_copy.device_brand.fillna('unknown')

# %%
df_ga_session_copy.utm_source.mode()
# Out:
# 0    ZpYIoDJMcFzVoPFsHGJL
# Name: utm_source, dtype: object

# %%
df_ga_session_copy.utm_source = df_ga_session_copy.utm_source.fillna('ZpYIoDJMcFzVoPFsHGJL')

# %%
df_ga_session_copy.utm_campaign = df_ga_session_copy.utm_campaign.fillna('unknown')

# %%
df_ga_session_copy.to_csv('ga_sessions_prep')

# %%
df_ga_hits_copy.to_csv('ga_hits_prep')

# %%
df_ga_hits.event_action.value_counts()
# Out:
# view_card                     3558985
# view_new_card                 3551009
# sub_landing                   1798117
# go_to_car_card                 973666
# sub_view_cars_click            791515
#                                ...
# click_on_android                    1
# new_year_road_help_btn              1
# titul_page_view                     1
# show_pos_status_declined            1
# survey_buy_after_sell_when          1
# Name: event_action, Length: 230, dtype: int64
